# %% [markdown]
# <a href="https://colab.research.google.com/github/anubhav006/Machine-Learning/blob/main/Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.linear_model import LogisticRegression
X=[[30],[40],[50],[70]]
Y=[0,0,1,1]
model=LogisticRegression()
model.fit(X,Y)
print(model.predict([[60]]))
# Out:
# [1]

# %%
from sklearn.linear_model import LinearRegression
X=[[30],[40],[50],[70]]
Y=[0,0,1,1]
model=LinearRegression()
model.fit(X,Y)
print(model.predict([[60]]))
# Out:
# [0.85714286]

# %%
from sklearn.linear_model import LinearRegression
Hours = [[6], [9], [12], [15], [18]]
Tem = [[18], [22], [30], [35], [28]]
model = LinearRegression()
model.fit(Hours,Tem)
print(model.predict([[10]]))
# Out:
# [[24.4]]

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
Hours = np.array([[6], [9], [12], [15], [18]])
Tem = np.array([[18], [22], [30], [35], [28]])
model = LinearRegression()
model.fit(Hours,Tem)
hour = np.array([[14]])
predicted_temp = model.predict(hour)
print("Temperature at 14 hrs:", predicted_temp[0])
# Out:
# Temperature at 14 hrs: [28.8]

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
X = np.array([
    [1000, 2],
    [1500, 3],
    [2000, 4],
    [2500, 5]
])
y= np.array([1000, 1500, 2000, 2500])
model = LinearRegression()
model.fit(X, y)
new_house = np.array([[1200, 3]])
predicted_price = model.predict(new_house)
print("Predicted price for the new house:", predicted_price[0])
# Out:
# Predicted price for the new house: 1200.0011999951996

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
x=[[500],[800],[1000],[1200],[1400]]
price=[[20],[30],[40],[50],[60]]
model=LinearRegression()
model.fit(x,price)
plt.scatter(x,price)
plt.plot(x,model.predict(x),color='red')
plt.xlabel('Area')
plt.ylabel('Price(lac)')
plt.title('House price prediction')
plt.show()

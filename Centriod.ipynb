# %% [markdown]
# <a href="https://colab.research.google.com/github/anubhav006/Machine-Learning/blob/main/Centriod.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.cluster import KMeans
import numpy as np

X = np.array([[1, 2],
              [1, 4],
              [5, 8],
              [6, 9]])

kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(X)

print("Centroids:")
print(kmeans.cluster_centers_)

print("Labels:", kmeans.labels_)
# Out:
# Centroids:
# [[5.5 8.5]
#  [1.  3. ]]
# Labels: [1 1 0 0]

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

data = pd.read_csv("data.csv")

X = data[['Hours']]
Y = data['Marks']

model = LinearRegression()

model.fit(X, Y)

prediction = model.predict([[6]])

print("Slope (m):", model.coef_)
print("Intercept (c):", model.intercept_)
print("Prediction for 6 hours:", prediction)
# Out:
# Slope (m): [20.]
# Intercept (c): 1.4210854715202004e-14
# Prediction for 6 hours: [120.]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print(model.predict([[100]]))
# Out:
# [2000.]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# <a href="https://colab.research.google.com/github/anubhav006/Machine-Learning/blob/main/Digit_recognization_system_using_SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

# %%
X = train_df.drop('label', axis=1)
y = train_df['label']

# Fill any NaN values in X with 0 before proceeding
X = X.fillna(0)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 100)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# fit_transform use to do some calculation and then do transformation
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.svm import SVC
rbf_model = SVC(kernel='rbf')
rbf_model.fit(X_train, y_train)
# Out:
# SVC()

# %%
#Model testing
y_rbf_pred = rbf_model.predict(X_test)

# %%
print("Predictad Values :\n",y_rbf_pred[10:15])
print ('Actual Values :\n',y_test[10:15])
# Out:
# Predictad Values :
#  [6 9 9 1 6]
# Actual Values :
#  876     6
# 656     9
# 27      9
# 134     1
# 1017    6
# Name: label, dtype: int64

# %%
from sklearn import metrics
acc_rbf= metrics.accuracy_score(y_test, y_rbf_pred)
print("accuracy:","{:.2f}".format(acc_rbf*100),"%")
# Out:
# accuracy: 88.16 %

# %%
for i in (np.random.randint(0,270,4)):
    two_d = (np.reshape(X_test[i], (28, 28)))
    plt.title('predicted label: {0}'. format(y_rbf_pred[i]))
    plt.imshow(two_d, cmap='gray')
    plt.show()
